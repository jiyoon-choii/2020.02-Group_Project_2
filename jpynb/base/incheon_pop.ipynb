# %%
import pandas as pd

# %%
inc = pd.read_csv('./csv/population/incheon_pop.csv', encoding='euc-kr', thousands=',')

# %%
inc
# Out:
#   incheon_GUGUN  incheon_pop
# 0         중   구       196155
# 1         동   구        94559
# 2         남   구       607867
# 3           연수구       501760
# 4           남동구       768394
# 5           부평구       744602
# 6           계양구       434104
# 7         서   구       771003
# 8           강화군       102795
# 9           옹진군        32560

# %%
inc['incheon_GUGUN'] = inc['incheon_GUGUN'].str.replace(" ","")

# %%
inc
# Out:
#   incheon_GUGUN  incheon_pop
# 0            중구       196155
# 1            동구        94559
# 2            남구       607867
# 3           연수구       501760
# 4           남동구       768394
# 5           부평구       744602
# 6           계양구       434104
# 7            서구       771003
# 8           강화군       102795
# 9           옹진군        32560

# %%
inc.columns
# Out:
# Index(['incheon_GUGUN', 'incheon_pop'], dtype='object')

# %%
dir = { 'incheon_GUGUN':'GUGUN'}

inc.rename(columns=dir, inplace=True)

# %%
inc
# Out:
#   GUGUN  incheon_pop
# 0    중구       196155
# 1    동구        94559
# 2    남구       607867
# 3   연수구       501760
# 4   남동구       768394
# 5   부평구       744602
# 6   계양구       434104
# 7    서구       771003
# 8   강화군       102795
# 9   옹진군        32560

# %%
inc1 = inc.rename(columns={'incheon_pop':'인구수'})
inc1
# Out:
#   GUGUN     인구수
# 0    중구  196155
# 1    동구   94559
# 2    남구  607867
# 3   연수구  501760
# 4   남동구  768394
# 5   부평구  744602
# 6   계양구  434104
# 7    서구  771003
# 8   강화군  102795
# 9   옹진군   32560

# %%
inc2 = inc1.set_index('GUGUN')

# %%
inc2.to_csv('./csv/2_INCHEON/jiyoon/incheon_gugun_pop.csv', encoding='euc-kr')

# %%
inc2
# Out:
#           인구수
# GUGUN
# 중구     196155
# 동구      94559
# 남구     607867
# 연수구    501760
# 남동구    768394
# 부평구    744602
# 계양구    434104
# 서구     771003
# 강화군    102795
# 옹진군     32560
