# %%
import pandas as pd

# %%
park = pd.read_csv('./csv/park/ulsan_park.csv', encoding='euc-kr')

# %%
print(park)
# Out:
#        공원번호         관리번호      공원명   공원구분                소재지도로명주소  \
# 0    285292  31710-00001     소공원1    소공원                     NaN
# 1    285291  31710-00002   동부소공원2    소공원                     NaN
# 2    285290  31710-00003   망향소공원4    소공원                     NaN
# 3    285289  31710-00004  언양소공원13    소공원                     NaN
# 4    285288  31710-00005    소공원20    소공원                     NaN
# ..      ...          ...      ...    ...                     ...
# 437  284855  31170-00031    주전2공원    소공원       울산광역시 동구 동부동 98번지
# 438  284854  31170-00165     양지공원  어린이공원   울산광역시 동구 화정동 638-12번지
# 439  284853  31170-00167    월봉골공원  어린이공원   울산광역시 동구 화정동 659-41번지
# 440  284852  31170-00002   남목생활공원  어린이공원  울산광역시 동구 동부동 161 164번지
# 441  284851  31170-00148     절골공원  어린이공원    울산광역시 동구 화정동 873-8번지
#
#                        소재지지번주소          위도         경도  공원면적(㎡) 공원보유시설(운동시설)  \
# 0        울산광역시 울주군 언양읍 서부리 402  129.117811  35.569455    920.0          NaN
# 1        울산광역시 울주군 언양읍 동부리 497  129.125096  35.573997   2684.0          NaN
# 2     울산광역시 울주군 두동면 삼정리 산141-2  129.178444  35.650934   3300.0          NaN
# 3    울산광역시 울주군 언양읍 남부리 336-156  129.129374  35.561575   3284.0          NaN
# 4        울산광역시 울주군 범서읍 굴화리 741  129.249304  35.547869    505.6          NaN
# ..                         ...         ...        ...      ...          ...
# 437       울산광역시 동구 동구 동부동 98번지  129.433778  35.551656  14300.0          NaN
# 438   울산광역시 동구 동구 화정동 638-12번지  129.428151  35.495973   1027.0          NaN
# 439   울산광역시 동구 동구 화정동 659-41번지  129.425388  35.492451   2018.0          NaN
# 440  울산광역시 동구 동구 동부동 161 164번지  129.433866  35.541352   6870.0          NaN
# 441    울산광역시 동구 동구 화정동 873-8번지  129.420524  35.492831   1510.0          NaN
#
#     공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설) 공원보유시설(기타시설)       지정고시일  \
# 0            NaN          NaN          NaN          NaN  2006-12-21
# 1            NaN          NaN          NaN          NaN  2006-11-16
# 2            NaN          NaN          NaN          NaN  2009-05-07
# 3            NaN          NaN          NaN          NaN  2012-02-16
# 4            NaN          NaN          NaN          NaN  2007-12-20
# ..           ...          ...          ...          ...         ...
# 437          NaN          NaN          NaN          NaN         NaN
# 438          NaN          NaN          NaN          NaN         NaN
# 439          NaN          NaN          NaN          NaN         NaN
# 440          NaN          NaN          NaN          NaN         NaN
# 441          NaN          NaN          NaN          NaN         NaN
#
#         데이터기준일자       관리기관명           연락처
# 0    2019-09-18  울산광역시 울주군청  052-204-1757
# 1    2019-09-18  울산광역시 울주군청  052-204-1757
# 2    2019-09-18  울산광역시 울주군청  052-204-1757
# 3    2019-09-18  울산광역시 울주군청  052-204-1757
# 4    2019-09-18  울산광역시 울주군청  052-204-1757
# ..          ...         ...           ...
# 437  2019-09-18   울산광역시 동구청  052-209-3744
# 438  2019-09-18   울산광역시 동구청  052-209-3744
# 439  2019-09-18   울산광역시 동구청  052-209-3744
# 440  2019-09-18   울산광역시 동구청  052-209-3744
# 441  2019-09-18   울산광역시 동구청  052-209-3744
#
# [442 rows x 18 columns]

# %%
park.columns
# Out:
# Index(['공원번호', '관리번호', '공원명', '공원구분', '소재지도로명주소', '소재지지번주소', '위도', '경도',
#        '공원면적(㎡)', '공원보유시설(운동시설)', '공원보유시설(유희시설)', '공원보유시설(편익시설)',
#        '공원보유시설(교양시설)', '공원보유시설(기타시설)', '지정고시일', '데이터기준일자', '관리기관명', '연락처'],
#       dtype='object')

# %%
park.tail()
# Out:
#        공원번호         관리번호     공원명   공원구분                소재지도로명주소  \
# 437  284855  31170-00031   주전2공원    소공원       울산광역시 동구 동부동 98번지
# 438  284854  31170-00165    양지공원  어린이공원   울산광역시 동구 화정동 638-12번지
# 439  284853  31170-00167   월봉골공원  어린이공원   울산광역시 동구 화정동 659-41번지
# 440  284852  31170-00002  남목생활공원  어린이공원  울산광역시 동구 동부동 161 164번지
# 441  284851  31170-00148    절골공원  어린이공원    울산광역시 동구 화정동 873-8번지
#
#                        소재지지번주소          위도         경도  공원면적(㎡) 공원보유시설(운동시설)  \
# 437       울산광역시 동구 동구 동부동 98번지  129.433778  35.551656  14300.0          NaN
# 438   울산광역시 동구 동구 화정동 638-12번지  129.428151  35.495973   1027.0          NaN
# 439   울산광역시 동구 동구 화정동 659-41번지  129.425388  35.492451   2018.0          NaN
# 440  울산광역시 동구 동구 동부동 161 164번지  129.433866  35.541352   6870.0          NaN
# 441    울산광역시 동구 동구 화정동 873-8번지  129.420524  35.492831   1510.0          NaN
#
#     공원보유시설(유희시설) 공원보유시설(편익시설) 공원보유시설(교양시설) 공원보유시설(기타시설) 지정고시일     데이터기준일자  \
# 437          NaN          NaN          NaN          NaN   NaN  2019-09-18
# 438          NaN          NaN          NaN          NaN   NaN  2019-09-18
# 439          NaN          NaN          NaN          NaN   NaN  2019-09-18
# 440          NaN          NaN          NaN          NaN   NaN  2019-09-18
# 441          NaN          NaN          NaN          NaN   NaN  2019-09-18
#
#          관리기관명           연락처
# 437  울산광역시 동구청  052-209-3744
# 438  울산광역시 동구청  052-209-3744
# 439  울산광역시 동구청  052-209-3744
# 440  울산광역시 동구청  052-209-3744
# 441  울산광역시 동구청  052-209-3744

# %%
park1 = park.loc[:, ['공원명','소재지도로명주소']]
park1
# Out:
#          공원명                소재지도로명주소
# 0       소공원1                     NaN
# 1     동부소공원2                     NaN
# 2     망향소공원4                     NaN
# 3    언양소공원13                     NaN
# 4      소공원20                     NaN
# ..       ...                     ...
# 437    주전2공원       울산광역시 동구 동부동 98번지
# 438     양지공원   울산광역시 동구 화정동 638-12번지
# 439    월봉골공원   울산광역시 동구 화정동 659-41번지
# 440   남목생활공원  울산광역시 동구 동부동 161 164번지
# 441     절골공원    울산광역시 동구 화정동 873-8번지
#
# [442 rows x 2 columns]

# %%
park2 = park1.fillna(0)

# %%
park3 = park2[park2.소재지도로명주소 != 0]
park3
# Out:
#         공원명                  소재지도로명주소
# 92     학산공원    울산광역시 중구 옥교8길 45 (학산동)
# 93     화진공원    울산광역시 중구 화진4길 49 (태화동)
# 94    반구정공원   울산광역시 중구 반구정4길 66 (반구동)
# 95     99공원  울산광역시 중구 당산5길 37-4 (우정동)
# 96     구교쉼터    울산광역시 중구 구교7길 12 (반구동)
# ..      ...                       ...
# 437   주전2공원         울산광역시 동구 동부동 98번지
# 438    양지공원     울산광역시 동구 화정동 638-12번지
# 439   월봉골공원     울산광역시 동구 화정동 659-41번지
# 440  남목생활공원    울산광역시 동구 동부동 161 164번지
# 441    절골공원      울산광역시 동구 화정동 873-8번지
#
# [350 rows x 2 columns]

# %%
small_addr = list()

addr = park3.loc[:, ['소재지도로명주소']].values 
for tmp in addr :
    small_addr.append(tmp[0].split(" ")[1])

print(small_addr)
# Out:
# ['중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '북구', '호계동', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '북구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '남구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구', '동구']

# %%
park3['GUGUN'] = small_addr
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
park3
# Out:
#         공원명                  소재지도로명주소 GUGUN
# 92     학산공원    울산광역시 중구 옥교8길 45 (학산동)    중구
# 93     화진공원    울산광역시 중구 화진4길 49 (태화동)    중구
# 94    반구정공원   울산광역시 중구 반구정4길 66 (반구동)    중구
# 95     99공원  울산광역시 중구 당산5길 37-4 (우정동)    중구
# 96     구교쉼터    울산광역시 중구 구교7길 12 (반구동)    중구
# ..      ...                       ...   ...
# 437   주전2공원         울산광역시 동구 동부동 98번지    동구
# 438    양지공원     울산광역시 동구 화정동 638-12번지    동구
# 439   월봉골공원     울산광역시 동구 화정동 659-41번지    동구
# 440  남목생활공원    울산광역시 동구 동부동 161 164번지    동구
# 441    절골공원      울산광역시 동구 화정동 873-8번지    동구
#
# [350 rows x 3 columns]

# %%
df = park3.drop(['소재지도로명주소'], axis='columns', inplace=True)
print(df)
# Out:
# None

# %%
park4 = park3.groupby('GUGUN').count()

# %%
park4
# Out:
#        공원명
# GUGUN
# 남구     108
# 동구      73
# 북구      52
# 중구     116
# 호계동      1

# %%
park5 = park4.rename(columns={'공원명':'공원수'})
park5
# Out:
#        공원수
# GUGUN
# 남구     108
# 동구      73
# 북구      52
# 중구     116
# 호계동      1

# %%
park5.to_csv('./csv/1_ULSAN/jiyoon/ulsan/ulsan_gugun_park.csv', encoding='euc-kr')
